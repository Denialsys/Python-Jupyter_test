# %%
import pandas as pd
df = pd.read_csv('stack-overflow-developer-survey-2022/survey_results_public.csv', nrows=100)

# %%
df
# Out:
#     ResponseId                                         MainBranch
# 0            1                                      None of these  \
# 1            2                     I am a developer by profession
# 2            3  I am not primarily a developer, but I write co...
# 3            4                     I am a developer by profession
# 4            5                     I am a developer by profession
# ..         ...                                                ...
# 95          96                     I am a developer by profession
# 96          97                     I am a developer by profession
# 97          98                     I am a developer by profession
# 98          99                     I am a developer by profession
# 99         100                     I am a developer by profession
#
#                                            Employment
# 0                                                 NaN  \
# 1                                 Employed, full-time
# ...

# %%
df.shape
# Out:
# (100, 79)

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ResponseId                      100 non-null    int64
#  1   MainBranch                      100 non-null    object
#  2   Employment                      96 non-null     object
#  3   RemoteWork                      82 non-null     object
#  4   CodingActivities                82 non-null     object
#  5   EdLevel                         96 non-null     object
#  6   LearnCode                       94 non-null     object
#  7   LearnCodeOnline                 68 non-null     object
#  8   LearnCodeCoursesCert            26 non-null     object
#  9   YearsCode                       95 non-null     object
#  10  YearsCodePro                    71 non-null     float64
#  11  DevType                         83 non-null     object
# ...

# %%
pd.set_option('display.max_columns', 79)

# %%
df
# Out:
#     ResponseId                                         MainBranch
# 0            1                                      None of these  \
# 1            2                     I am a developer by profession
# 2            3  I am not primarily a developer, but I write co...
# 3            4                     I am a developer by profession
# 4            5                     I am a developer by profession
# ..         ...                                                ...
# 95          96                     I am a developer by profession
# 96          97                     I am a developer by profession
# 97          98                     I am a developer by profession
# 98          99                     I am a developer by profession
# 99         100                     I am a developer by profession
#
#                                            Employment
# 0                                                 NaN  \
# 1                                 Employed, full-time
# ...
